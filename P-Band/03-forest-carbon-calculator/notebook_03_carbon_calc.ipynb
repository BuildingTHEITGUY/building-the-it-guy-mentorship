# %% [markdown]
# # Mission 3: Forest Carbon Calculator
#
# **Goal:** Convert biomass maps into actual carbon stock estimates for a specific region.
#
# **Time:** ~1.5 hours | **Difficulty:** Intermediate
#
# ---
#
# ## Learning Goals
#
# - The biomass-to-carbon conversion formula (C = 0.5 x AGB)
# - Spatial clipping with geopandas + rasterio.mask
# - How to calculate total carbon in tonnes for any region
# - How to produce a report-ready carbon estimate and map

# %% [markdown]
# ---
#
# ## Step 1: Import Libraries

# %%
import rasterio
import rasterio.mask
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

print('Libraries loaded! Ready for Mission 3.')

# %% [markdown]
# ---
#
# ## Step 2: Load Data

# %%
# Your data loading code here

# %% [markdown]
# ---
#
# ## Step 3: Process and Visualize

# %%
# Your processing and visualization code here

# %% [markdown]
# ---
#
# ## Mission Complete Checklist
#
# - [ ] Produced a visible output (map, chart, or saved file)
# - [ ] Understood the core concept
# - [ ] Saved my results
# - [ ] Ready for the next mission
#
# **Next up:** Mission 4 - Subsurface Detective (04-subsurface-detective/)
