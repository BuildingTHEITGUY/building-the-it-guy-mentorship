# %% [markdown]
# # Mission 5: ML-Powered SAR Classifier
#
# **Goal:** Train a deep learning model to classify land cover using SAR data from the M3LEO dataset.
#
# **Time:** ~3 hours | **Difficulty:** Advanced
#
# ---
#
# ## Learning Goals
#
# - Loading the M3LEO dataset from Hugging Face
# - Building a CNN classifier with PyTorch Lightning
# - Training on real SAR satellite imagery
# - Evaluating model performance with confusion matrix and metrics

# %% [markdown]
# ---
#
# ## Step 1: Import Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorch_lightning as pl
from datasets import load_dataset
import matplotlib.pyplot as plt

print('Libraries loaded! Ready for Mission 5.')
print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')

# %% [markdown]
# ---
#
# ## Step 2: Load Data

# %%
# Your data loading code here

# %% [markdown]
# ---
#
# ## Step 3: Process and Visualize

# %%
# Your processing and visualization code here

# %% [markdown]
# ---
#
# ## Mission Complete Checklist
#
# - [ ] Produced a visible output (map, chart, or saved file)
# - [ ] Understood the core concept
# - [ ] Saved my results
# - [ ] Ready for the next mission
