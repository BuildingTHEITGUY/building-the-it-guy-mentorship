# %% [markdown]
# # Mission 2: BIOMASS Data Explorer
#
# **Goal:** Load ESA BIOMASS Level-2 products and compare P-band vs C-band.
#
# **Time:** ~1 hour | **Difficulty:** Intermediate
#
# ---
#
# ## Learning Goals
#
# - The difference between P-band and C-band penetration depth
# - How to work with Above Ground Biomass (AGB) raster products
# - Side-by-side satellite comparison techniques
# - Why wavelength matters for forest observation

# %% [markdown]
# ---
#
# ## Step 1: Import Libraries

# %%
import rasterio
from rasterio.plot import show
import numpy as np
import matplotlib.pyplot as plt

print('Libraries loaded! Ready for Mission 2.')

# %% [markdown]
# ---
#
# ## Step 2: Load Data

# %%
# Your data loading code here

# %% [markdown]
# ---
#
# ## Step 3: Process and Visualize

# %%
# Your processing and visualization code here

# %% [markdown]
# ---
#
# ## Mission Complete Checklist
#
# - [ ] Produced a visible output (map, chart, or saved file)
# - [ ] Understood the core concept
# - [ ] Saved my results
# - [ ] Ready for the next mission
#
# **Next up:** Mission 3 - Forest Carbon Calculator (03-forest-carbon-calculator/)
